# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import random

# %%
m1 = np.random.rand(3, 3)
m2 = np.random.rand(3, 3)
m3 = np.random.rand(6, 6)
m4 = np.random.rand(6, 6)
m5 = np.random.rand(12, 12)
m6 = np.random.rand(12, 12)
m7 = np.random.rand(24, 24)
m8 = np.random.rand(24, 24)
m9 = np.random.rand(48, 48)
m10 = np.random.rand(48, 48)
m11 = np.random.rand(96, 96)
m12 = np.random.rand(96, 96)
m13 = np.random.rand(192, 192)
m14 = np.random.rand(192, 192)
m15 = np.random.rand(384, 384)
m16 = np.random.rand(384, 384)

# %%
t = []
start = time.perf_counter()
n1 = np.dot(m1,m2)
end = time.perf_counter()
t.append(end-start)

start = time.perf_counter()
n2 = np.dot(m3,m4)
end = time.perf_counter()
t.append(end-start)

start = time.perf_counter()
n3 = np.dot(m5,m6)
end = time.perf_counter()
t.append(end-start)

start = time.perf_counter()
n4 = np.dot(m7,m8)
end = time.perf_counter()
t.append(end-start)

start = time.perf_counter()
n5 = np.dot(m9,m10)
end = time.perf_counter()
t.append(end-start)

start = time.perf_counter()
n6 = np.dot(m11,m12)
end = time.perf_counter()
t.append(end-start)

start = time.perf_counter()
n7 = np.dot(m13,m14)
end = time.perf_counter()
t.append(end-start)

start = time.perf_counter()
n8 = np.dot(m15,m16)
end = time.perf_counter()
t.append(end-start)

# %%
t
# Out:
# [0.00028292275965213776,
#  8.757412433624268e-05,
#  7.68415629863739e-05,
#  8.829683065414429e-05,
#  0.00024724751710891724,
#  0.0007557868957519531,
#  0.0010829586535692215,
#  0.004129227250814438]

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8]
plt.scatter(x, t)
plt.ylim(0, 0.002)
plt.xlabel("size of matrix *2")
plt.ylabel("Time to compute")
plt.title("Computation time for multiplying matries")
plt.show()
