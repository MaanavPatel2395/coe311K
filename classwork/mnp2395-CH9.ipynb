# %% [markdown]
# # Plot each data point. Plot the line y=0.95x+0.59

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# Part 1:

# %%
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
y = m*X + c
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
plt.plot(X, y)
plt.scatter(X, Y)
plt.xlim(0,6)
plt.title("Least Squares Fit")
plt.grid(True)
plt.show()

# %% [markdown]
# Part 2:

# %%
x = np.array([random.uniform(0, 10) for i in range(100)])
y = np.array([random.uniform(0, 10) for i in range(100)])

# %%
x.sort()
A = np.vstack([x, np.ones(len(x))]).T
m, c = np.linalg.lstsq(A, y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
y_line = m*x + c
# Out:
# Slope: -0.12810902243546496, Intercept: 5.417340642161596

# %%
plt.plot(x, y_line)
plt.scatter(x, y)
plt.xlim(0,6)
plt.title("Least Squares Fit")
plt.grid(True)
plt.show()

# %% [markdown]
# Part 3:

# %%
m = -0.29
b = 0.94
x = np.arange(0, 10.1, 0.1)
y = m*x + b
noise = [random.uniform(-0.5, 0.5) for i in range(len(y_rand))]
y_rand = noise + y

# %%
plt.plot(x, y, color = 'red')
plt.scatter(x, y_rand, color = 'blue', label = 'scatter')
plt.title("Least Squares Fit")
plt.grid(True)
plt.show()
