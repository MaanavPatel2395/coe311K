# %% [markdown]
# # Coding Challenge 7

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Define Functions:

# %%
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    errors = []
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        errors.append(np.linalg.norm(x_new - x, ord=np.inf))
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k, errors
        x = x_new
    return x, max_iterations, errors

# %%
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    errors = []
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        # Check for convergence
        errors.append(np.linalg.norm(x_new - x, ord=np.inf))
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k, errors
        x = x_new
    return x, max_iterations, errors

# %% [markdown]
# Part A:

# %%
A = np.array([
	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)
b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)
x0 = np.zeros_like(b)
xJ, iterationsJ, errorsJ = jacobi(A, b, x0, 0.000001, 10000)
xG, iterationsG, errorsG = gauss_seidel(A, b, x0, 0.000001, 100)

# %%
print(xJ, iterationsJ)
print(xG, iterationsG)
# Out:
# [1.0000005 1.0000005 1.0000005 1.0000005 1.0000005] 3462
# [0.99999926 1.00000045 0.99999989 0.99999997 1.00000005] 20

# %% [markdown]
# PartB:

# %%
A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1])
x1 = np.zeros_like(b)

# %%
xJ, iterationsJ, errorsJ = jacobi(A, b, x1, 0.000001, 100)
xG, iterationsG, errorsG = gauss_seidel(A, b, x1, 0.000001, 100)

# %%
print(xJ, iterationsJ)
print(xG, iterationsG)
# Out:
# [1 0] 1
# [1 0] 1

# %% [markdown]
# Part C:

# %%
A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1.0001])
x1 = np.zeros_like(b)

# %%
xJ, iterationsJ, errorsJ = jacobi(A, b, x1, 0.000001, 100)
xG, iterationsG, errorsG = gauss_seidel(A, b, x1, 0.000001, 100)

# %%
print(xJ, iterationsJ)
print(xG, iterationsG)
# Out:
# [0.         0.00498727] 100
# [0.99014933 0.00994967] 100

# %% [markdown]
# Part D:

# %%
A = np.array([
	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)
b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)
x2 = np.zeros_like(b)

# %%
def isDiagDom(A):
    n = len(b)
    A0 = np.abs(A)
    for i in range(n):
        for j in range(n):
            rowsum = A0[i][j]-A0[i][i]
            if(A0[i][i]<rowsum):
                return False
    return True

# %%
print(isDiagDom(A))
# Out:
# True
