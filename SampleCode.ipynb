# %% [markdown]
# Hello Python! This is Sample Code

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Monte Carlo Method

# %%
import random

def approxPi(samples):
    counter = 0
    for i in range(0, samples):
        x = random.uniform(-1,1)
        y = random.uniform(-1,1)
        n = (x**2 + y**2)
        if (n<1):
            counter = counter + 1
    Circle = counter / samples
    APi = Circle*4

# %%
# Out:
# 3.1392
